# %% [markdown]
# <a href="https://colab.research.google.com/github/yuanaf/assets/blob/main/Safety_Behind_the_Wheels_with_Add_Ons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Load the Dataset

# %%
url = "https://drive.google.com/uc?export=download&id=1xoNhU-QjTp30RpTPKWxhf358Sp-eU83Y"
df = pd.read_csv(url)
df.head(20)
#df.tail(5)
#df.sample(10)
# Out:
#    Age_band_of_driver Sex_of_driver   Educational_level  \
# 0               18-30          Male   Above high school
# 1               31-50          Male  Junior high school
# 2               18-30          Male  Junior high school
# 3               18-30          Male  Junior high school
# 4               18-30          Male  Junior high school
# 5               31-50          Male             Unknown
# 6               18-30          Male  Junior high school
# 7               18-30          Male  Junior high school
# 8               18-30          Male  Junior high school
# 9               18-30          Male  Junior high school
# 10              18-30          Male   Above high school
# 11              31-50          Male   Above high school
# 12              18-30          Male  Junior high school
# 13              31-50          Male  Junior high school
# 14              31-50          Male  Junior high school
# 15              18-30        Female  Junior high school
# 16              18-30          Male  Junior high school
# 17              18-30          Male   Elementary school
# 18              18-30          Male  Junior high school
# 19              18-30          Male  Junior high school
#
#    Vehicle_driver_relation Driving_experience             Lanes_or_Medians  \
# 0                 Employee              1-2yr                      Unknown
# 1                 Employee         Above 10yr            Undivided Two way
# 2                 Employee              1-2yr                        other
# 3                 Employee             5-10yr                        other
# 4                 Employee              2-5yr                        other
# 5                  Unknown            Unknown                      Unknown
# 6                 Employee              2-5yr            Undivided Two way
# 7                 Employee              2-5yr                        other
# 8                 Employee         Above 10yr                        other
# 9                 Employee              1-2yr            Undivided Two way
# 10                   Owner              1-2yr                        other
# 11                Employee         No Licence            Undivided Two way
# 12                Employee              1-2yr  Double carriageway (median)
# 13                Employee             5-10yr                        other
# 14                Employee         Above 10yr            Undivided Two way
# 15                Employee         Above 10yr                      One way
# 16                   Owner             5-10yr            Undivided Two way
# 17                Employee              2-5yr                        other
# 18                Employee              2-5yr                        other
# 19                Employee          Below 1yr                      One way
#
#    Types_of_Junction Road_surface_type       Light_conditions  \
# 0        No junction     Asphalt roads               Daylight
# 1        No junction     Asphalt roads               Daylight
# 2        No junction     Asphalt roads               Daylight
# 3            Y Shape       Earth roads  Darkness - lights lit
# 4            Y Shape     Asphalt roads  Darkness - lights lit
# 5            Y Shape           Unknown               Daylight
# 6           Crossing           Unknown               Daylight
# 7            Y Shape     Asphalt roads               Daylight
# 8            Y Shape       Earth roads               Daylight
# 9            Y Shape     Asphalt roads               Daylight
# 10       No junction     Asphalt roads               Daylight
# 11       No junction       Earth roads               Daylight
# 12       No junction     Asphalt roads               Daylight
# 13       No junction     Asphalt roads               Daylight
# 14       No junction     Asphalt roads               Daylight
# 15           Y Shape     Asphalt roads  Darkness - lights lit
# 16           Y Shape     Asphalt roads  Darkness - lights lit
# 17           Y Shape     Asphalt roads  Darkness - lights lit
# 18           Y Shape     Asphalt roads  Darkness - lights lit
# 19           Y Shape     Asphalt roads               Daylight
#
#    Weather_conditions                        Type_of_collision  \
# 0              Normal  Collision with roadside-parked vehicles
# 1              Normal           Vehicle with vehicle collision
# 2              Normal          Collision with roadside objects
# 3              Normal           Vehicle with vehicle collision
# 4              Normal           Vehicle with vehicle collision
# 5              Normal           Vehicle with vehicle collision
# 6              Normal           Vehicle with vehicle collision
# 7              Normal           Vehicle with vehicle collision
# 8              Normal  Collision with roadside-parked vehicles
# 9              Normal  Collision with roadside-parked vehicles
# 10             Normal                   Collision with animals
# 11             Normal                   Collision with animals
# 12             Normal                   Collision with animals
# 13             Normal                   Collision with animals
# 14             Normal                   Collision with animals
# 15            Raining                   Collision with animals
# 16            Raining                   Collision with animals
# 17            Raining                   Collision with animals
# 18            Raining                   Collision with animals
# 19             Normal                   Collision with animals
#
#    Vehicle_movement              Pedestrian_movement  \
# 0    Going straight                 Not a Pedestrian
# 1    Going straight                 Not a Pedestrian
# 2    Going straight                 Not a Pedestrian
# 3    Going straight                 Not a Pedestrian
# 4    Going straight                 Not a Pedestrian
# 5            U-Turn                 Not a Pedestrian
# 6   Moving Backward                 Not a Pedestrian
# 7            U-Turn                 Not a Pedestrian
# 8    Going straight  Crossing from driver's nearside
# 9            U-Turn                 Not a Pedestrian
# 10         Turnover                 Not a Pedestrian
# 11   Going straight                 Not a Pedestrian
# 12   Going straight                 Not a Pedestrian
# 13    Waiting to go                 Not a Pedestrian
# 14   Going straight                 Not a Pedestrian
# 15   Going straight                 Not a Pedestrian
# 16   Going straight                 Not a Pedestrian
# 17   Going straight                 Not a Pedestrian
# 18  Moving Backward                 Not a Pedestrian
# 19   Going straight                 Not a Pedestrian
#
#              Cause_of_accident  Accident_severity
# 0              Moving Backward                  2
# 1                   Overtaking                  2
# 2    Changing lane to the left                  1
# 3   Changing lane to the right                  2
# 4                   Overtaking                  2
# 5                  Overloading                  2
# 6                        Other                  2
# 7       No priority to vehicle                  2
# 8   Changing lane to the right                  2
# 9              Moving Backward                  1
# 10   Changing lane to the left                  1
# 11   No priority to pedestrian                  1
# 12               No distancing                  2
# 13      No priority to vehicle                  2
# 14               No distancing                  1
# 15               No distancing                  1
# 16             Moving Backward                  2
# 17  Changing lane to the right                  1
# 18   No priority to pedestrian                  2
# 19             Moving Backward                  1

# %% [markdown]
# ## Feature Descriptions

# %% [markdown]
# Context
#
# > This data set is collected from Addis Ababa Sub city police departments for Masters research work.
#
#
# Content
#
# > The data set has been prepared from manual records of road traffic accident of the year 2017-20. All the sensitive information have been excluded during data encoding and finally it has 32 features and 12316 instances of the accident. Then it is preprocessed and for identification of major causes of the accident by analyzing it using different machine learning classification algorithms algorithms.

# %% [markdown]
# Features Description
#
# >Age_band_of_driver: Groups drivers by age.
#
# > Sex_of_driver: Indicates driver's gender.
#
# > Educational_level: Records driver's education level.
#
# > Vehicle_driver_relation: Defines driver-vehicle relationship.
#
# > Driving_experience: Captures years of driving experience.
#
# > Lanes_or_Medians: Specifies if lanes or medians are present.
#
# > Types_of_Junction: Describes type of junction.
#
# > Road_surface_type: Identifies road surface type.
#
# > Light_conditions: Records lighting conditions.
#
# > Weather_conditions: Describes weather during the accident.
#
# > Type_of_collision: Categorizes collision type.
#
# > Vehicle_movement: Describes vehicle movement.
#
# > Pedestrian_movement: Indicates pedestrian movement.
#
# > Cause_of_accident: Lists cause of the accident.
#
# > Accident_severity: Rates accident severity as 0, 1, or 2, where higher numbers indicate more severity.

# %% [markdown]
# # Mission 1: Who's on The Road?

# %% [markdown]
# Please answer all the questions below to help guide you through analyzing the road traffic accident data. These questions are designed to help you understand key trends, patterns, and insights, focusing specifically on the factors contributing to accidents and their severity.

# %% [markdown]
# ## What column will you use to answer Mission 1's question?
# Let's find out the columns list in our dataset.

# %%
df.columns
# Out:
# Index(['Age_band_of_driver', 'Sex_of_driver', 'Educational_level',
#        'Vehicle_driver_relation', 'Driving_experience', 'Lanes_or_Medians',
#        'Types_of_Junction', 'Road_surface_type', 'Light_conditions',
#        'Weather_conditions', 'Type_of_collision', 'Vehicle_movement',
#        'Pedestrian_movement', 'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
# value_counts() in pandas counts unique values in a column and sorts them by frequency.
df['Age_band_of_driver'].value_counts()
# Out:
# Age_band_of_driver
# 18-30       4271
# 31-50       4087
# Over 51     1585
# Unknown     1548
# Under 18     825
# Name: count, dtype: int64

# %% [markdown]
# ## Who has more accidents, men or women?

# %%
#Your answer here
df['Sex_of_driver'].value_counts()
# Out:
# Sex_of_driver
# Male       11437
# Female       701
# Unknown      178
# Name: count, dtype: int64

# %% [markdown]
# # Mission 2: What Happens After Dark?

# %% [markdown]
# ## Do accidents happen more during the day or night?

# %%
df['Light_conditions'].value_counts()
# Out:
# Light_conditions
# Daylight                   8798
# Darkness - lights lit      3286
# Darkness - no lighting      192
# Darkness - lights unlit      40
# Name: count, dtype: int64

# %% [markdown]
# ## What percentage of accidents occur during daylight?

# %%
df['Light_conditions'].value_counts(normalize=True)
# Out:
# Light_conditions
# Daylight                   0.714355
# Darkness - lights lit      0.266807
# Darkness - no lighting     0.015589
# Darkness - lights unlit    0.003248
# Name: proportion, dtype: float64

# %% [markdown]
# Approximately 71% of accidents occur during daylight.

# %% [markdown]
# # Mission 3: When Weather Goes Wild.

# %% [markdown]
# ## Does weather play a big role in road traffic accidents?

# %%
df["Weather_conditions"].value_counts(normalize=True)
# Out:
# Weather_conditions
# Normal               0.817067
# Raining              0.108071
# Other                0.024034
# Unknown              0.023709
# Cloudy               0.010149
# Windy                0.007957
# Snow                 0.004953
# Raining and Windy    0.003248
# Fog or mist          0.000812
# Name: proportion, dtype: float64

# %% [markdown]
# The vast majority of accidents (81.7%) happen under normal weather conditions. This suggests that weather is not the primary factor in most accidents. Among abnormal weather conditions, rain is the most significant contributor, accounting for 10.8% of accidents.

# %% [markdown]
# ## Which abnormal weather condition is the most significant contributor to accidents?

# %%
#Your answer here
# Raining

# %% [markdown]
# # Mission 4: How Bad Is It? 🚑

# %% [markdown]
# ## Which weather conditions have the highest percentage of accident severity (2)?

# %%
df.groupby("Weather_conditions")["Accident_severity"].value_counts(normalize=True)
# Out:
# Weather_conditions  Age_band_of_driver  Sex_of_driver  Educational_level   Vehicle_driver_relation  Driving_experience  Lanes_or_Medians                                  Types_of_Junction  Road_surface_type  Light_conditions         Type_of_collision               Vehicle_movement  Pedestrian_movement                                                            Cause_of_accident           Accident_severity
# Cloudy              18-30               Female         Elementary school   Employee                 Below 1yr           other                                             Crossing           Asphalt roads      Darkness - lights lit    Vehicle with vehicle collision  Going straight    Not a Pedestrian                                                               No distancing               2                    0.008000
#                                                        Junior high school  Employee                 2-5yr               Undivided Two way                                 Unknown            Asphalt roads      Daylight                 Vehicle with vehicle collision  Going straight    Not a Pedestrian                                                               No priority to vehicle      2                    0.008000
#                                         Male           Above high school   Employee                 5-10yr              Two-way (divided with broken lines road marking)  O Shape            Gravel roads       Darkness - lights lit    Vehicle with vehicle collision  Going straight    Not a Pedestrian                                                               Changing lane to the left   2                    0.008000
#                                                                            Owner                    1-2yr               Undivided Two way                                 Y Shape            Asphalt roads      Daylight                 Vehicle with vehicle collision  Going straight    Not a Pedestrian                                                               Moving Backward             2                    0.008000
#                                                        Elementary school   Employee                 1-2yr               Two-way (divided with broken lines road marking)  Y Shape            Unknown            Daylight                 Vehicle with vehicle collision  Going straight    Not a Pedestrian                                                               Changing lane to the right  2                    0.008000
#                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# Windy               Unknown             Male           Elementary school   Employee                 5-10yr              Two-way (divided with broken lines road marking)  No junction        Asphalt roads      Darkness - no lighting   Vehicle with vehicle collision  Getting off       Not a Pedestrian                                                               Changing lane to the left   2                    0.010204
#                                                        High school         Employee                 Above 10yr          Undivided Two way                                 Y Shape            Asphalt roads      Daylight                 Vehicle with vehicle collision  Going straight    Not a Pedestrian                                                               No priority to pedestrian   2                    0.010204
#                                                        Junior high school  Employee                 Above 10yr          One way                                           No junction        Asphalt roads      Daylight                 Collision with pedestrians      Reversing         Crossing from nearside - masked by parked or statioNot a Pedestrianry vehicle  Overtaking                  1                    0.010204
#                                                                                                                         Undivided Two way                                 Y Shape            Asphalt roads      Darkness - lights lit    Vehicle with vehicle collision  Other             Not a Pedestrian                                                               Overspeed                   2                    0.010204
#                                                                                                     Below 1yr           Two-way (divided with broken lines road marking)  No junction        Asphalt roads      Darkness - lights unlit  Vehicle with vehicle collision  Going straight    Not a Pedestrian                                                               Changing lane to the right  2                    0.010204
# Name: proportion, Length: 11926, dtype: float64

# %% [markdown]
# The weather condition that causes the highest percentage of accident severity (2) is 'Raining and Windy,' with 95% of accidents being classified as severity (2).

# %% [markdown]
# # Challenge: Missing Values

# %% [markdown]
# ## Are there any missing values in the dataset?

# %%
df.isnull()
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                   False          False              False
# 1                   False          False              False
# 2                   False          False              False
# 3                   False          False              False
# 4                   False          False              False
# ...                   ...            ...                ...
# 12311               False          False              False
# 12312               False          False              False
# 12313               False          False              False
# 12314               False          False              False
# 12315               False          False              False
#
#        Vehicle_driver_relation  Driving_experience  Lanes_or_Medians  \
# 0                        False               False             False
# 1                        False               False             False
# 2                        False               False             False
# 3                        False               False             False
# 4                        False               False             False
# ...                        ...                 ...               ...
# 12311                    False               False             False
# 12312                    False               False             False
# 12313                    False               False             False
# 12314                    False               False             False
# 12315                    False               False             False
#
#        Types_of_Junction  Road_surface_type  Light_conditions  \
# 0                  False              False             False
# 1                  False              False             False
# 2                  False              False             False
# 3                  False              False             False
# 4                  False              False             False
# ...                  ...                ...               ...
# 12311              False              False             False
# 12312              False              False             False
# 12313              False              False             False
# 12314              False              False             False
# 12315              False              False             False
#
#        Weather_conditions  Type_of_collision  Vehicle_movement  \
# 0                   False              False             False
# 1                   False              False             False
# 2                   False              False             False
# 3                   False              False             False
# 4                   False              False             False
# ...                   ...                ...               ...
# 12311               False              False             False
# 12312               False              False             False
# 12313               False              False             False
# 12314               False              False             False
# 12315               False              False             False
#
#        Pedestrian_movement  Cause_of_accident  Accident_severity
# 0                    False              False              False
# 1                    False              False              False
# 2                    False              False              False
# 3                    False              False              False
# 4                    False              False              False
# ...                    ...                ...                ...
# 12311                False              False              False
# 12312                False              False              False
# 12313                False              False              False
# 12314                False              False              False
# 12315                False              False              False
#
# [12316 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# Age_band_of_driver         0
# Sex_of_driver              0
# Educational_level          0
# Vehicle_driver_relation    0
# Driving_experience         0
# Lanes_or_Medians           0
# Types_of_Junction          0
# Road_surface_type          0
# Light_conditions           0
# Weather_conditions         0
# Type_of_collision          0
# Vehicle_movement           0
# Pedestrian_movement        0
# Cause_of_accident          0
# Accident_severity          0
# dtype: int64

# %% [markdown]
# ## How about 'Unknown' values in the dataset? Are they considered missing values?

# %% [markdown]
# Yes, 'Unknown' values in the dataset can be considered missing values as they represent a lack of specific information.

# %%
df['Age_band_of_driver'].value_counts()
# Out:
# Age_band_of_driver
# 18-30       4271
# 31-50       4087
# Over 51     1585
# Unknown     1548
# Under 18     825
# Name: count, dtype: int64

# %%
columns = df.columns
for i in columns:
  print(df[i].value_counts())
  print("\n")
# Out:
# Age_band_of_driver
# 18-30       4271
# 31-50       4087
# Over 51     1585
# Unknown     1548
# Under 18     825
# Name: count, dtype: int64
#
#
# Sex_of_driver
# Male       11437
# Female       701
# Unknown      178
# Name: count, dtype: int64
#
#
# Educational_level
# Junior high school    7619
# Elementary school     2163
# High school           1110
# Unknown                841
# Above high school      362
# Writing & reading      176
# Illiterate              45
# Name: count, dtype: int64
#
#
# Vehicle_driver_relation
# Employee    9627
# Owner       1973
# Unknown      593
# Other        123
# Name: count, dtype: int64
#
#
# Driving_experience
# 5-10yr        3363
# 2-5yr         2613
# Above 10yr    2262
# 1-2yr         1756
# Below 1yr     1342
# Unknown        829
# No Licence     118
# unknown         33
# Name: count, dtype: int64
#
#
# Lanes_or_Medians
# Two-way (divided with broken lines road marking)    4411
# Undivided Two way                                   3796
# other                                               1660
# Double carriageway (median)                         1020
# One way                                              845
# Unknown                                              442
# Two-way (divided with solid lines road marking)      142
# Name: count, dtype: int64
#
#
# Types_of_Junction
# Y Shape        4543
# No junction    3837
# Crossing       2177
# Unknown        1078
# Other           445
# O Shape         164
# T Shape          60
# X Shape          12
# Name: count, dtype: int64
#
#
# Road_surface_type
# Asphalt roads                       11296
# Earth roads                           358
# Gravel roads                          242
# Unknown                               172
# Other                                 167
# Asphalt roads with some distress       81
# Name: count, dtype: int64
#
#
# Light_conditions
# Daylight                   8798
# Darkness - lights lit      3286
# Darkness - no lighting      192
# Darkness - lights unlit      40
# Name: count, dtype: int64
#
#
# Weather_conditions
# Normal               10063
# Raining               1331
# Other                  296
# Unknown                292
# Cloudy                 125
# Windy                   98
# Snow                    61
# Raining and Windy       40
# Fog or mist             10
# Name: count, dtype: int64
#
#
# Type_of_collision
# Vehicle with vehicle collision             8774
# Collision with roadside objects            1786
# Collision with pedestrians                  896
# Rollover                                    397
# Collision with animals                      171
# Unknown                                     169
# Collision with roadside-parked vehicles      54
# Fall from vehicles                           34
# Other                                        26
# With Train                                    9
# Name: count, dtype: int64
#
#
# Vehicle_movement
# Going straight         8158
# Moving Backward         985
# Other                   937
# Reversing               563
# Turnover                489
# Unknown                 396
# Getting off             339
# Entering a junction     193
# Overtaking               96
# Stopping                 61
# U-Turn                   50
# Waiting to go            39
# Parked                   10
# Name: count, dtype: int64
#
#
# Pedestrian_movement
# Not a Pedestrian                                                                                                                         11390
# Crossing from nearside - masked by parked or statioNot a Pedestrianry vehicle                                                              337
# Unknown or other                                                                                                                           293
# Crossing from driver's nearside                                                                                                            140
# Crossing from offside - masked by  parked or statioNot a Pedestrianry vehicle                                                               72
# In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing)                                                              46
# Walking along in carriageway, back to traffic                                                                                               18
# In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing) - masked by parked or statioNot a Pedestrianry vehicle       13
# Walking along in carriageway, facing traffic                                                                                                 7
# Name: count, dtype: int64
#
#
# Cause_of_accident
# No distancing                           2263
# Changing lane to the right              1808
# Changing lane to the left               1473
# Driving carelessly                      1402
# No priority to vehicle                  1207
# Moving Backward                         1137
# No priority to pedestrian                721
# Other                                    456
# Overtaking                               430
# Driving under the influence of drugs     340
# Driving to the left                      284
# Getting off the vehicle improperly       197
# Driving at high speed                    174
# Overturning                              149
# Turnover                                  78
# Overspeed                                 61
# Overloading                               59
# Drunk driving                             27
# Unknown                                   25
# Improper parking                          25
# Name: count, dtype: int64
#
#
# Accident_severity
# 2    10415
# 1     1743
# 0      158
# Name: count, dtype: int64
